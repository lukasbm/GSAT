# %%
import sys

sys.path.append('../src')

import torch
from copy import deepcopy
from pathlib import Path
from gsat import GSAT, ExtractorMLP
from utils import get_data_loaders, get_model, set_seed, Criterion, init_metric_dict, load_checkpoint
from trainer import run_one_epoch, update_best_epoch_res, get_viz_idx, visualize_results
from datetime import datetime
# Out:
# /home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/outdated/__init__.py:36: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54274/2056357225.py", line 8, in <module>
#     from gsat import GSAT, ExtractorMLP
#   File "/home/lukas/Documents/GSAT/example/gsat.py", line 10, in <module>
#     from utils import MLP, reorder_like
#   File "/home/lukas/Documents/GSAT/src/utils/__init__.py", line 1, in <module>
#     from .get_data_loaders import get_data_loaders
#   File "/home/lukas/Documents/GSAT/src/utils/get_data_loaders.py", line 3, in <module>
#     from ogb.graphproppred import PygGraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/__init__.py", line 2, in <module>
#     from .dataset import GraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/dataset.py", line 5, in <module>
#     from ogb.utils.url import decide_download, download_url, extract_zip
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/__init__.py", line 2, in <module>
#     from .mol import smiles2graph
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/mol.py", line 3, in <module>
#     from rdkit import Chem
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/Chem/__init__.py", line 18, in <module>
#     from rdkit import DataStructs
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/DataStructs/__init__.py", line 13, in <module>
#     from rdkit.DataStructs import cDataStructs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54274/2056357225.py", line 8, in <module>
#     from gsat import GSAT, ExtractorMLP
#   File "/home/lukas/Documents/GSAT/example/gsat.py", line 10, in <module>
#     from utils import MLP, reorder_like
#   File "/home/lukas/Documents/GSAT/src/utils/__init__.py", line 1, in <module>
#     from .get_data_loaders import get_data_loaders
#   File "/home/lukas/Documents/GSAT/src/utils/get_data_loaders.py", line 3, in <module>
#     from ogb.graphproppred import PygGraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/__init__.py", line 2, in <module>
#     from .dataset import GraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/dataset.py", line 5, in <module>
#     from ogb.utils.url import decide_download, download_url, extract_zip
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/__init__.py", line 2, in <module>
#     from .mol import smiles2graph
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/mol.py", line 3, in <module>
#     from rdkit import Chem
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/Chem/__init__.py", line 20, in <module>
#     from rdkit.Chem import rdchem
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54274/2056357225.py", line 8, in <module>
#     from gsat import GSAT, ExtractorMLP
#   File "/home/lukas/Documents/GSAT/example/gsat.py", line 10, in <module>
#     from utils import MLP, reorder_like
#   File "/home/lukas/Documents/GSAT/src/utils/__init__.py", line 1, in <module>
#     from .get_data_loaders import get_data_loaders
#   File "/home/lukas/Documents/GSAT/src/utils/get_data_loaders.py", line 3, in <module>
#     from ogb.graphproppred import PygGraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/__init__.py", line 2, in <module>
#     from .dataset import GraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/dataset.py", line 5, in <module>
#     from ogb.utils.url import decide_download, download_url, extract_zip
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/__init__.py", line 2, in <module>
#     from .mol import smiles2graph
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/mol.py", line 3, in <module>
#     from rdkit import Chem
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/Chem/__init__.py", line 24, in <module>
#     from rdkit.Chem.rdmolops import *
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54274/2056357225.py", line 8, in <module>
#     from gsat import GSAT, ExtractorMLP
#   File "/home/lukas/Documents/GSAT/example/gsat.py", line 10, in <module>
#     from utils import MLP, reorder_like
#   File "/home/lukas/Documents/GSAT/src/utils/__init__.py", line 1, in <module>
#     from .get_data_loaders import get_data_loaders
#   File "/home/lukas/Documents/GSAT/src/utils/get_data_loaders.py", line 3, in <module>
#     from ogb.graphproppred import PygGraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/__init__.py", line 2, in <module>
#     from .dataset import GraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/dataset.py", line 5, in <module>
#     from ogb.utils.url import decide_download, download_url, extract_zip
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/__init__.py", line 2, in <module>
#     from .mol import smiles2graph
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/mol.py", line 3, in <module>
#     from rdkit import Chem
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/Chem/Draw/__init__.py", line 20, in <module>
#     from rdkit.Chem import rdDepictor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib64/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib64/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/usr/lib64/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/usr/lib64/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ipykernel/zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_54274/2056357225.py", line 8, in <module>
#     from gsat import GSAT, ExtractorMLP
#   File "/home/lukas/Documents/GSAT/example/gsat.py", line 10, in <module>
#     from utils import MLP, reorder_like
#   File "/home/lukas/Documents/GSAT/src/utils/__init__.py", line 1, in <module>
#     from .get_data_loaders import get_data_loaders
#   File "/home/lukas/Documents/GSAT/src/utils/get_data_loaders.py", line 3, in <module>
#     from ogb.graphproppred import PygGraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/__init__.py", line 2, in <module>
#     from .dataset import GraphPropPredDataset
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/graphproppred/dataset.py", line 5, in <module>
#     from ogb.utils.url import decide_download, download_url, extract_zip
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/__init__.py", line 2, in <module>
#     from .mol import smiles2graph
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/ogb/utils/mol.py", line 3, in <module>
#     from rdkit import Chem
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/rdkit/Chem/Draw/__init__.py", line 21, in <module>
#     from rdkit.Chem.Draw import rdMolDraw2D
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# /home/lukas/Documents/GSAT/venv/lib64/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))

# %%
model_name = 'PNA'

method_name = 'GSAT'
cuda_id = 0
seed = 0
set_seed(seed)

# %%
data_dir = Path('../data')
device = torch.device(f'cuda:{cuda_id}' if cuda_id >= 0 else 'cpu')

if model_name == 'GIN':
    model_config = {'model_name': 'GIN', 'hidden_size': 64, 'n_layers': 2, 'dropout_p': 0.3, 'use_edge_attr': True}
else:
    assert model_name == 'PNA'
    model_config = {'model_name': 'PNA', 'hidden_size': 80, 'n_layers': 4, 'dropout_p': 0.3, 'use_edge_attr': False,
                    'atom_encoder': True, 'aggregators': ['mean', 'min', 'max', 'std'], 'scalers': False}

metric_dict = deepcopy(init_metric_dict)
model_dir = data_dir / dataset_name / 'logs' / (
        datetime.now().strftime("%m_%d_%Y-%H_%M_%S") + '-' + dataset_name + '-' + model_name + '-seed' + str(
    seed) + '-' + method_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       8     model_config = {'model_name': 'PNA', 'hidden_size': 80, 'n_layers': 4, 'dropout_p': 0.3, 'use_edge_attr': False,
#       9                     'atom_encoder': True, 'aggregators': ['mean', 'min', 'max', 'std'], 'scalers': False}
#      11 metric_dict = deepcopy(init_metric_dict)
# ---> 12 model_dir = data_dir / dataset_name / 'logs' / (
#      13         datetime.now().strftime("%m_%d_%Y-%H_%M_%S") + '-' + dataset_name + '-' + model_name + '-seed' + str(
#      14     seed) + '-' + method_name)
#
# NameError: name 'dataset_name' is not defined

# %%
loaders, test_set, x_dim, edge_attr_dim, num_class, aux_info = get_data_loaders(data_dir, dataset_name, batch_size=128,
                                                                                random_state=seed,
                                                                                splits={'train': 0.8, 'valid': 0.1,
                                                                                        'test': 0.1},
                                                                                mutag_x=True if dataset_name == 'mutag' else False)
model_config['deg'] = aux_info['deg']

# %%
clf = get_model(x_dim, edge_attr_dim, num_class, aux_info['multi_label'], model_config, device)
extractor = ExtractorMLP(model_config['hidden_size'], learn_edge_att=False).to(device)
optimizer = torch.optim.Adam(list(extractor.parameters()) + list(clf.parameters()), lr=1e-3, weight_decay=3.0e-6)
criterion = Criterion(num_class, aux_info['multi_label'])
gsat = GSAT(clf, extractor, criterion, optimizer, learn_edge_att=False, final_r=0.7)

# %%
for epoch in range(100):
    train_res = run_one_epoch(gsat, loaders['train'], epoch, 'train', dataset_name, seed, model_config['use_edge_attr'],
                              aux_info['multi_label'])
    valid_res = run_one_epoch(gsat, loaders['valid'], epoch, 'valid', dataset_name, seed, model_config['use_edge_attr'],
                              aux_info['multi_label'])
    test_res = run_one_epoch(gsat, loaders['test'], epoch, 'test', dataset_name, seed, model_config['use_edge_attr'],
                             aux_info['multi_label'])

    metric_dict = update_best_epoch_res(gsat, train_res, valid_res, test_res, metric_dict, dataset_name, epoch,
                                        model_dir)
    print(f'[Seed {seed}, Epoch: {epoch}]: Best Epoch: {metric_dict["metric/best_clf_epoch"]}, '
          f'Best Val Pred ACC/ROC: {metric_dict["metric/best_clf_valid"]:.3f}, Best Test Pred ACC/ROC: {metric_dict["metric/best_clf_test"]:.3f}, '
          f'Best Test X AUROC: {metric_dict["metric/best_x_roc_test"]:.3f}')
    print('=' * 50)
    print('=' * 50)

# %%
best_epoch = metric_dict['metric/best_clf_epoch']
load_checkpoint(gsat, model_dir, model_name=f'gsat_epoch_{best_epoch}', map_location=device)

# %%
num_viz_samples = 10
assert aux_info['multi_label'] is False

all_viz_set = get_viz_idx(test_set, dataset_name, num_viz_samples)
visualize_results(gsat, all_viz_set, test_set, num_viz_samples, dataset_name, model_config['use_edge_attr'])
